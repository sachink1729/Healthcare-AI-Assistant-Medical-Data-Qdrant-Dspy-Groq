# %%
# pip install qdrant-client groq sentence-transformers dspy-ai fastembed gradio pyjwt --upgrade

# %% [markdown]
# ## Dataset

# %%
import pandas as pd
df = pd.read_csv("healthcare_dataset.csv")

# %%
df[:5]
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results
# 0        Normal
# 1  Inconclusive
# 2        Normal
# 3      Abnormal
# 4      Abnormal

# %%
# Function to format each row into a single string
def format_row(row):
    return (
        f"Name: {row['Name']}, Age: {row['Age']}, Gender: {row['Gender']}, "
        f"Blood Type: {row['Blood Type']}, Medical Condition: {row['Medical Condition']}, "
        f"Date of Admission: {row['Date of Admission']}, Doctor: {row['Doctor']}, "
        f"Hospital: {row['Hospital']}, Insurance Provider: {row['Insurance Provider']}, "
        f"Billing Amount: {row['Billing Amount']}, Room Number: {row['Room Number']}, "
        f"Admission Type: {row['Admission Type']}, Discharge Date: {row['Discharge Date']}, "
        f"Medication: {row['Medication']}, Test Results: {row['Test Results']}"
        "\n\n".lower()
    )

# Apply the function to each row and create a new column with the formatted text
df['formatted_text'] = df.apply(format_row, axis=1)

# Convert the formatted text into a list (or any other format you need)
text_data = df['formatted_text'].tolist()

# %%
from random import shuffle
sampled_dataset = text_data[:128]
shuffle(sampled_dataset)

# %%
sampled_dataset[:5]
# Out:
# ['name: dr. lauren clark dds, age: 19, gender: male, blood type: b+, medical condition: cancer, date of admission: 2020-10-26, doctor: brian wagner, hospital: plc jimenez, insurance provider: unitedhealthcare, billing amount: 49833.70771785452, room number: 302, admission type: elective, discharge date: 2020-11-17, medication: lipitor, test results: inconclusive\n\n',
#  'name: william hill, age: 38, gender: female, blood type: a+, medical condition: cancer, date of admission: 2023-05-16, doctor: matthew walker, hospital: lindsey inc, insurance provider: cigna, billing amount: 39476.94751437997, room number: 428, admission type: elective, discharge date: 2023-06-01, medication: aspirin, test results: abnormal\n\n',
#  'name: adrian buckley, age: 22, gender: female, blood type: a-, medical condition: arthritis, date of admission: 2023-10-11, doctor: julie ramirez, hospital: lin thompson wells, and, insurance provider: blue cross, billing amount: 42696.52116389919, room number: 102, admission type: urgent, discharge date: 2023-10-27, medication: penicillin, test results: normal\n\n',
#  'name: paul henderson, age: 72, gender: female, blood type: ab+, medical condition: hypertension, date of admission: 2020-05-15, doctor: stephanie kramer, hospital: wilson group, insurance provider: medicare, billing amount: 33211.29541901202, room number: 109, admission type: emergency, discharge date: 2020-06-08, medication: paracetamol, test results: inconclusive\n\n',
#  'name: dr. eileen thompson, age: 59, gender: male, blood type: a+, medical condition: asthma, date of admission: 2021-08-02, doctor: donna martinez md, hospital: and sons smith, insurance provider: aetna, billing amount: 25250.05242821613, room number: 119, admission type: urgent, discharge date: 2021-08-12, medication: lipitor, test results: inconclusive\n\n']

# %% [markdown]
# ## Encode Texts

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer("BAAI/bge-large-en-v1.5", device='cuda')

# %%
vectors = model.encode(sampled_dataset)

# %%
vectors[0].shape
# Out:
# (1024,)

# %% [markdown]
# ## Qdrant Cloud

# %%
import os
os.environ['QDRANT__SERVICE__API_KEY']="qdrant_api_key"
os.environ['QDRANT__SERVICE__JWT_RBAC']='true'

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams

# Initialize the client

client = QdrantClient(
    url="https://b3cc6dd2-4f57-4e59-8799-e66f63cccca3.us-east4-0.gcp.cloud.qdrant.io:6333",
    # url='http://localhost:6333',
    api_key=os.environ['QDRANT__SERVICE__API_KEY'],
)

# %%
client.recreate_collection(
    collection_name="phi_data",
    vectors_config=VectorParams(size=1024, distance=Distance.COSINE),
)

client.upload_collection(
    collection_name="phi_data",
    ids=[i for i in range(len(sampled_dataset))],
    vectors=vectors,
    parallel=4,
    max_retries=3,
)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_19844\1623567680.py:1: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   client.recreate_collection(

# %%
def get_context(text):
    query_vector = model.encode(text)

    hits = client.search(
        collection_name="phi_data",
        query_vector=query_vector,
        limit=3  # Return 5 closest points
    )
    s=''
    for x in [sampled_dataset[i.id] for i in hits]:
        s = s + x
    return s

# %% [markdown]
# ## Qdrant Local server with JWT - Role based access

# %% [markdown]
# Start your qdrant docker container with these commands:
#
# >docker run -p 6333:6333 -p 6334:6334 -e QDRANT__SERVICE__API_KEY=eXaMplE12345Key67890Api -e QDRANT__SERVICE__JWT_RBAC=true qdrant/qdrant

# %%
import jwt
import time


# API key used as the secret to sign the token
api_key = 'eXaMplE12345Key67890Api'


# Current time in seconds since the Unix epoch
current_time = int(time.time())


# JWT payload
payload = {
    'exp': current_time + 3600,  # Token expires in 1 hour
    'value_exists': {
        'collection': 'demo_collection',
        'matches': [
            {'key': 'user', 'value': 'John'}
        ]
    },
    "access": [
    {
        "collection": "demo_collection",
        "access": "r",
        "payload": {
            "user": "John"
      }
    }
  ]  # Read-only global access
}


# Encode the JWT token
encoded_jwt = jwt.encode(payload, api_key, algorithm='HS256')


# Print the JWT token
print(encoded_jwt)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJleHAiOjE3MTYzMTA2MDgsInZhbHVlX2V4aXN0cyI6eyJjb2xsZWN0aW9uIjoiZGVtb19jb2xsZWN0aW9uIiwibWF0Y2hlcyI6W3sia2V5IjoidXNlciIsInZhbHVlIjoiSm9obiJ9XX0sImFjY2VzcyI6W3siY29sbGVjdGlvbiI6ImRlbW9fY29sbGVjdGlvbiIsImFjY2VzcyI6InIiLCJwYXlsb2FkIjp7InVzZXIiOiJKb2huIn19XX0.7ald90UIk7hI5d57S0vDfo_bdatNsi20XURlhUee_Nw

# %%
# create a dummy collection with the original API key

root_client = QdrantClient(
    url="http://localhost:6333",
    api_key="eXaMplE12345Key67890Api",
)

root_client.recreate_collection(
    collection_name="dummy",
    vectors_config=VectorParams(size=1024, distance=Distance.COSINE),
)

root_client.upload_collection(
    collection_name="dummy",
    ids=[i for i in range(len(sampled_dataset))],
    vectors=vectors,
    parallel=4,
    max_retries=3,
)
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_17700\4217143445.py:8: DeprecationWarning: `recreate_collection` method is deprecated and will be removed in the future. Use `collection_exists` to check collection existence and `create_collection` instead.
#   root_client.recreate_collection(

# %%
your_role_key = encoded_jwt

# using this key you can ONLY read the collection

# %%
# but what if you try to upload points to dummy instead of reading it, you will get forbidden error!

from qdrant_client import QdrantClient, models
import numpy as np

client = QdrantClient(
    url="http://localhost:6333",
    api_key=your_role_key,
)

data = np.array(list([0.1]*1024))
print(data.shape)

client.upload_points(
    collection_name="dummy",
    points=[
        models.PointStruct(
            id="5c56c793-69f3-4fbf-87e6-c4bf54c28c26",
            vector=data,
        )])
# Out:
# (1024,)
# WARNING:root:Batch upload failed 1 times. Retrying...
# WARNING:root:Batch upload failed 2 times. Retrying...
# WARNING:root:Batch upload failed 3 times. Retrying...
# ---------------------------------------------------------------------------
# UnexpectedResponse                        Traceback (most recent call last)
# Cell In[26], line 14
#      11 data = np.array(list([0.1]*1024))
#      12 print(data.shape)
# ---> 14 client.upload_points(
#      15     collection_name="dummy",
#      16     points=[
#      17         models.PointStruct(
#      18             id="5c56c793-69f3-4fbf-87e6-c4bf54c28c26",
#      19             vector=data,
#      20         )])
#
# File c:\Users\ASUS\anaconda3\envs\new\lib\site-packages\qdrant_client\qdrant_client.py:1933, in QdrantClient.upload_points(self, collection_name, points, batch_size, parallel, method, max_retries, wait, shard_key_selector, **kwargs)
#    1908 """Upload points to the collection
#    1909
#    1910 Similar to `upload_collection` method, but operates with points, rather than vector and payload individually.
#    (...)
#    1929
#    1930 """
#    1931 assert len(kwargs) == 0, f"Unknown arguments: {list(kwargs.keys())}"
# -> 1933 return self._client.upload_points(
#    1934     collection_name=collection_name,
#    1935     points=points,
#    1936     batch_size=batch_size,
#    1937     parallel=parallel,
#    1938     method=method,
#    1939     max_retries=max_retries,
#    1940     wait=wait,
#    1941     shard_key_selector=shard_key_selector,
#    1942 )
#
# File c:\Users\ASUS\anaconda3\envs\new\lib\site-packages\qdrant_client\qdrant_remote.py:2405, in QdrantRemote.upload_points(self, collection_name, points, batch_size, parallel, method, max_retries, wait, shard_key_selector, **kwargs)
#    2389 def upload_points(
#    2390     self,
#    2391     collection_name: str,
#    (...)
#    2399     **kwargs: Any,
#    2400 ) -> None:
#    2401     batches_iterator = self._updater_class.iterate_records_batches(
#    2402         records=points, batch_size=batch_size
#    2403     )
# -> 2405     self._upload_collection(
#    2406         batches_iterator=batches_iterator,
#    2407         collection_name=collection_name,
#    2408         max_retries=max_retries,
#    2409         parallel=parallel,
#    2410         method=method,
#    2411         wait=wait,
#    2412         shard_key_selector=shard_key_selector,
#    2413     )
#
# File c:\Users\ASUS\anaconda3\envs\new\lib\site-packages\qdrant_client\qdrant_remote.py:2357, in QdrantRemote._upload_collection(self, batches_iterator, collection_name, max_retries, parallel, method, wait, shard_key_selector)
#    2355 if parallel == 1:
#    2356     updater = self._updater_class.start(**updater_kwargs)
# -> 2357     for _ in updater.process(batches_iterator):
#    2358         pass
#    2359 else:
#
# File c:\Users\ASUS\anaconda3\envs\new\lib\site-packages\qdrant_client\uploader\rest_uploader.py:81, in RestBatchUploader.process(self, items)
#      79 def process(self, items: Iterable[Any]) -> Generator[bool, None, None]:
#      80     for batch in items:
# ---> 81         yield upload_batch(
#      82             self.openapi_client,
#      83             self.collection_name,
#      84             batch,
#      85             shard_key_selector=self._shard_key_selector,
#      86             max_retries=self.max_retries,
#      87             wait=self._wait,
#      88         )
#
# File c:\Users\ASUS\anaconda3\envs\new\lib\site-packages\qdrant_client\uploader\rest_uploader.py:47, in upload_batch(openapi_client, collection_name, batch, max_retries, shard_key_selector, wait)
#      44         logging.warning(f"Batch upload failed {attempt + 1} times. Retrying...")
#      46         if attempt == max_retries - 1:
# ---> 47             raise e
#      48 return True
#
# File c:\Users\ASUS\anaconda3\envs\new\lib\site-packages\qdrant_client\uploader\rest_uploader.py:37, in upload_batch(openapi_client, collection_name, batch, max_retries, shard_key_selector, wait)
#      35 for attempt in range(max_retries):
#      36     try:
# ---> 37         openapi_client.points_api.upsert_points(
#      38             collection_name=collection_name,
#      39             point_insert_operations=PointsList(points=points, shard_key=shard_key_selector),
#      40             wait=wait,
#      41         )
#      42         break
#      43     except Exception as e:
#
# File c:\Users\ASUS\anaconda3\envs\new\lib\site-packages\qdrant_client\http\api\points_api.py:1439, in SyncPointsApi.upsert_points(self, collection_name, wait, ordering, point_insert_operations)
#    1429 def upsert_points(
#    1430     self,
#    1431     collection_name: str,
#    (...)
#    1434     point_insert_operations: m.PointInsertOperations = None,
#    1435 ) -> m.InlineResponse2007:
#    1436     """
#    1437     Perform insert + updates on points. If point with given ID already exists - it will be overwritten.
#    1438     """
# -> 1439     return self._build_for_upsert_points(
#    1440         collection_name=collection_name,
#    1441         wait=wait,
#    1442         ordering=ordering,
#    1443         point_insert_operations=point_insert_operations,
#    1444     )
#
# File c:\Users\ASUS\anaconda3\envs\new\lib\site-packages\qdrant_client\http\api\points_api.py:738, in _PointsApi._build_for_upsert_points(self, collection_name, wait, ordering, point_insert_operations)
#     736 if "Content-Type" not in headers:
#     737     headers["Content-Type"] = "application/json"
# --> 738 return self.api_client.request(
#     739     type_=m.InlineResponse2007,
#     740     method="PUT",
#     741     url="/collections/{collection_name}/points",
#     742     headers=headers if headers else None,
#     743     path_params=path_params,
#     744     params=query_params,
#     745     content=body,
#     746 )
#
# File c:\Users\ASUS\anaconda3\envs\new\lib\site-packages\qdrant_client\http\api_client.py:76, in ApiClient.request(self, type_, method, url, path_params, **kwargs)
#      74     kwargs["timeout"] = int(kwargs["params"]["timeout"])
#      75 request = self._client.build_request(method, url, **kwargs)
# ---> 76 return self.send(request, type_)
#
# File c:\Users\ASUS\anaconda3\envs\new\lib\site-packages\qdrant_client\http\api_client.py:99, in ApiClient.send(self, request, type_)
#      97     except ValidationError as e:
#      98         raise ResponseHandlingException(e)
# ---> 99 raise UnexpectedResponse.for_response(response)
#
# UnexpectedResponse: Unexpected Response: 403 (Forbidden)
# Raw response content:
# b'Invalid JWT, stateful validation failed'

# %% [markdown]
# ## Dspy pipeline

# %%
from dspy.retrieve.qdrant_rm import QdrantRM

# %%
qdrant_retriever_model = QdrantRM("phi_data", client, k=3)

# %%
import dspy
llama3 = dspy.GROQ(model='llama3-8b-8192', api_key ="<groq_api_key>" )

# %%
dspy.settings.configure(rm=qdrant_retriever_model, lm=llama3)

class GenerateAnswer(dspy.Signature):
    """Answer questions with logical factoid answers."""

    context = dspy.InputField(desc="will contain PHI medical data of patients matched with the query")
    question = dspy.InputField()
    answer = dspy.OutputField(desc="an answer between 10 to 20 words")

# %%
class RAG(dspy.Module):
    def __init__(self, num_passages=3):
        super().__init__()

        self.retrieve = dspy.Retrieve(k=num_passages)
        self.generate_answer = dspy.ChainOfThought(GenerateAnswer)

    def forward(self, question):
        context = get_context(question)
        prediction = self.generate_answer(context=context, question=question)
        return dspy.Prediction(context=context, answer=prediction.answer)

# %% [markdown]
# ## Test Ineference

# %%
uncompiled_rag = RAG()

# %%
def respond(query):
    response = uncompiled_rag(query)
    return response.answer

# %%
respond("steven james")
# Out:
# 'Steven James is the doctor mentioned in the patient data.'

# %%
llama3.inspect_history(n=1)
# Out:
# Answer questions with logical factoid answers.
#
# ---
#
# Follow the following format.
#
# Context: will contain PHI medical data of patients matched with the query
#
# Question: ${question}
#
# Reasoning: Let's think step by step in order to ${produce the answer}. We ...
#
# Answer: an answer between 10 to 20 words
#
# ---
#
# Context:
# name: mark ford, age: 18, gender: male, blood type: b+, medical condition: asthma, date of admission: 2022-10-18, doctor: steven james, hospital: luna inc, insurance provider: unitedhealthcare, billing amount: 28837.6770525072, room number: 227, admission type: elective, discharge date: 2022-11-11, medication: aspirin, test results: abnormal
#
# name: catherine gardner, age: 79, gender: female, blood type: a-, medical condition: hypertension, date of admission: 2019-08-19, doctor: david ruiz, hospital: james ltd, insurance provider: medicare, billing amount: 25503.673806852043, room number: 144, admission type: elective, discharge date: 2019-08-26, medication: lipitor, test results: abnormal
#
# name: kyle wiley, age: 40, gender: female, blood type: ab-, medical condition: cancer, date of admission: 2021-01-21, doctor: stephen carr, hospital: taylor-nguyen, insurance provider: aetna, billing amount: 6733.990947068834, room number: 300, admission type: urgent, discharge date: 2021-02-06, medication: ibuprofen, test results: normal
#
#
#
# Question: steven james
#
# Reasoning: Let's think step by step in order to Context: will contain PHI medical data of patients matched with the query
#
# Question: steven james
#
# Reasoning: Let's think step by step in order to find the doctor's name mentioned in the patient data. We ...
#
# Answer: Steven James is the doctor mentioned in the patient data. 	 (and 273 other completions)
# "\n\n\nAnswer questions with logical factoid answers.\n\n---\n\nFollow the following format.\n\nContext: will contain PHI medical data of patients matched with the query\n\nQuestion: ${question}\n\nReasoning: Let's think step by step in order to ${produce the answer}. We ...\n\nAnswer: an answer between 10 to 20 words\n\n---\n\nContext:\nname: mark ford, age: 18, gender: male, blood type: b+, medical condition: asthma, date of admission: 2022-10-18, doctor: steven james, hospital: luna inc, insurance provider: unitedhealthcare, billing amount: 28837.6770525072, room number: 227, admission type: elective, discharge date: 2022-11-11, medication: aspirin, test results: abnormal\n\nname: catherine gardner, age: 79, gender: female, blood type: a-, medical condition: hypertension, date of admission: 2019-08-19, doctor: david ruiz, hospital: james ltd, insurance provider: medicare, billing amount: 25503.673806852043, room number: 144, admission type: elective, discharge date: 2019-08-26, medication: lipitor, test results: abnormal\n\nname: kyle wiley, age: 40, gender: female, blood type: ab-, medical condition: cancer, date of admission: 2021-01-21, doctor: stephen carr, hospital: taylor-nguyen, insurance provider: aetna, billing amount: 6733.990947068834, room number: 300, admission type: urgent, discharge date: 2021-02-06, medication: ibuprofen, test results: normal\n\n\n\nQuestion: steven james\n\nReasoning: Let's think step by step in order to\x1b Context: will contain PHI medical data of patients matched with the query\n\nQuestion: steven james\n\nReasoning: Let's think step by step in order to find the doctor's name mentioned in the patient data. We ...\n\nAnswer: Steven James is the doctor mentioned in the patient data.\x1b\x1b \t (and 273 other completions)\x1b\n\n\n"

# %% [markdown]
# ## Gradio UI

# %%
import gradio as gr


with gr.Blocks() as demo:
    chatbot = gr.Chatbot()
    msg = gr.Textbox()
    clear = gr.ClearButton([msg, chatbot])
    
    def respond(query, chat_history):
        response = uncompiled_rag(query)
        chat_history.append((query, response.answer))
        return "", chat_history

    msg.submit(respond, [msg, chatbot], [msg, chatbot])

# %%
demo.launch()
# demo.launch(share=True) if using colab
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
sampled_dataset[67]
# Out:
# 'name: kayla padilla, age: 63, gender: male, blood type: b-, medical condition: asthma, date of admission: 2020-09-24, doctor: jermaine peters, hospital: and morales jennings cook,, insurance provider: aetna, billing amount: 34774.351127057584, room number: 152, admission type: emergency, discharge date: 2020-10-08, medication: penicillin, test results: inconclusive\n\n'
